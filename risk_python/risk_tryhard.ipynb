# %%
import pandas_datareader as web
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib as plt

# %%
df= pd.read_excel("returns.xlsx",index_col = "Date")

# %%
df = df.iloc[::-1]

# %%
ewma_cov = df.ewm(com=0.94).cov()

# %%
ewma_cov = ewma_cov.iloc[::-1]

# %%
ewma_cov
# Out:
#                            ^FCHI    BNP.PA     AI.PA     RI.PA         ^GSPC  \
# Date
# 2020-02-14 GBP5Y    1.402630e-02  0.014531  0.029115 -0.032839  2.309017e-03
#            GBP3Y    1.374567e-02  0.015605  0.026736 -0.031724  2.700716e-03
#            GBP2Y    1.270532e-02  0.014819  0.024830 -0.029473  2.391050e-03
#            GBP1Y    9.383296e-03  0.011179  0.020071 -0.021749  1.245583e-03
#            USD10Y   1.252714e-02  0.014909  0.021034 -0.018146  4.242145e-03
#            USD7Y    1.630351e-02  0.021785  0.020201 -0.026195  6.860106e-03
#            USD5Y    1.333981e-02  0.018455  0.011244 -0.020861  7.071061e-03
#            USD3Y    1.219854e-02  0.014166  0.024120 -0.020206  2.632456e-03
#            USD2Y    1.286533e-02  0.016434  0.026255 -0.020817  2.215118e-03
#            USD1Y    2.425808e-03  0.007091 -0.001694  0.003956  1.785587e-03
#            USD6MTH -1.827585e-04 -0.002928 -0.005180 -0.003821  1.350807e-03
#            USD3MTH  2.839369e-03 -0.000345  0.008877 -0.010938  1.550675e-04
#            EUR10Y   8.617188e-03  0.007605  0.016369 -0.016706  2.622176e-03
#            EUR7Y    7.966468e-03  0.006418  0.016775 -0.017276  1.840618e-03
#            EUR5Y    7.080421e-03  0.005341  0.015890 -0.016377  1.318028e-03
#            EUR3Y    5.331544e-03  0.003823  0.012091 -0.012267  1.001334e-03
#            EUR2Y    3.778208e-03  0.002669  0.007877 -0.008091  9.770830e-04
#            EUR1Y    1.348615e-03  0.000905  0.000914 -0.002099  1.006900e-03
#            EUR6MTH -3.782374e-04 -0.000377 -0.004042  0.001544  9.952638e-04
#            EUR3MTH -1.416348e-03 -0.001165 -0.006990  0.003487  9.663296e-04
#            GBP/EUR  6.299506e-06 -0.000006  0.000043 -0.000028 -7.092737e-06
#            USD/EUR  9.472437e-07 -0.000004  0.000011 -0.000010 -2.391499e-06
#            BAS      3.762882e-05  0.000070 -0.000012 -0.000043  3.617068e-05
#            DPW      3.522325e-05  0.000038  0.000094 -0.000062  6.274866e-07
#            ADS      2.444633e-05  0.000051 -0.000027 -0.000023  2.390433e-05
#            ^GDAXI   2.506856e-05  0.000035  0.000034 -0.000034  1.032721e-05
#            BA       7.032869e-05  0.000065  0.000244 -0.000174 -1.740899e-05
#            VOD      5.803797e-05  0.000087  0.000080 -0.000136  1.166398e-05
#            BATS     2.078366e-06  0.000001  0.000033  0.000018 -3.543220e-06
#            SDR     -1.201895e-05  0.000007 -0.000058  0.000072  1.271983e-05
# ...                          ...       ...       ...       ...           ...
# 2007-12-31 EUR2Y             NaN       NaN       NaN       NaN           NaN
#            EUR1Y             NaN       NaN       NaN       NaN           NaN
#            EUR6MTH           NaN       NaN       NaN       NaN           NaN
#            EUR3MTH           NaN       NaN       NaN       NaN           NaN
#            GBP/EUR           NaN       NaN       NaN       NaN           NaN
#            USD/EUR           NaN       NaN       NaN       NaN           NaN
#            BAS               NaN       NaN       NaN       NaN           NaN
#            DPW               NaN       NaN       NaN       NaN           NaN
#            ADS               NaN       NaN       NaN       NaN           NaN
#            ^GDAXI            NaN       NaN       NaN       NaN           NaN
#            BA                NaN       NaN       NaN       NaN           NaN
#            VOD               NaN       NaN       NaN       NaN           NaN
#            BATS              NaN       NaN       NaN       NaN           NaN
#            SDR               NaN       NaN       NaN       NaN           NaN
#            EZJ               NaN       NaN       NaN       NaN           NaN
#            ^FTSE             NaN       NaN       NaN       NaN           NaN
#            F                 NaN       NaN       NaN       NaN           NaN
#            GE                NaN       NaN       NaN       NaN           NaN
#            AMD               NaN       NaN       NaN       NaN           NaN
#            NFLX              NaN       NaN       NaN       NaN           NaN
#            TSCO              NaN       NaN       NaN       NaN           NaN
#            ANSS              NaN       NaN       NaN       NaN           NaN
#            MA                NaN       NaN       NaN       NaN           NaN
#            AAPL              NaN       NaN       NaN       NaN           NaN
#            ROST              NaN       NaN       NaN       NaN           NaN
#            ^GSPC             NaN       NaN       NaN       NaN           NaN
#            RI.PA             NaN       NaN       NaN       NaN           NaN
#            AI.PA             NaN       NaN       NaN       NaN           NaN
#            BNP.PA            NaN       NaN       NaN       NaN           NaN
#            ^FCHI             NaN       NaN       NaN       NaN           NaN
#
#                             ROST      AAPL        MA      ANSS          TSCO  \
# Date
# 2020-02-14 GBP5Y   -7.578526e-03  0.016419 -0.012039  0.010817  8.286257e-03
#            GBP3Y   -6.890273e-03  0.016854 -0.010940  0.011352  8.595981e-03
#            GBP2Y   -6.455624e-03  0.015121 -0.010411  0.010400  7.969084e-03
#            GBP1Y   -5.008349e-03  0.009145 -0.009022  0.006935  5.476929e-03
#            USD10Y  -1.136014e-03  0.016830 -0.005495  0.011643  7.479931e-03
#            USD7Y   -1.907640e-03  0.027770 -0.004014  0.017696  1.168925e-02
#            USD5Y   -8.645059e-04  0.027683 -0.000009  0.016630  1.078951e-02
#            USD3Y   -3.085524e-03  0.013189 -0.008272  0.009836  6.277426e-03
#            USD2Y   -2.971427e-03  0.012055 -0.009394  0.009826  5.896668e-03
#            USD1Y    3.977708e-03  0.005227  0.003933  0.004042  7.093104e-04
#            USD6MTH -1.823139e-03  0.006728  0.002524  0.001662  2.408706e-03
#            USD3MTH -3.862749e-03  0.002956 -0.004664  0.001475  2.501878e-03
#            EUR10Y  -3.195614e-03  0.011401 -0.005931  0.007179  6.385004e-03
#            EUR7Y   -3.957946e-03  0.009474 -0.006786  0.005905  5.721529e-03
#            EUR5Y   -4.143793e-03  0.007741 -0.006881  0.004831  5.037235e-03
#            EUR3Y   -3.363418e-03  0.005747 -0.005461  0.003610  3.877329e-03
#            EUR2Y   -2.254716e-03  0.004661 -0.003495  0.002860  2.962302e-03
#            EUR1Y   -4.130499e-04  0.003400 -0.000045  0.001793  1.691191e-03
#            EUR6MTH  8.403287e-04  0.002611  0.002458  0.001003  8.813893e-04
#            EUR3MTH  1.556874e-03  0.002147  0.003952  0.000504  4.255828e-04
#            GBP/EUR -1.410562e-05 -0.000011 -0.000024 -0.000006 -3.652269e-06
#            USD/EUR -5.724663e-06 -0.000004 -0.000008 -0.000003 -1.063992e-07
#            BAS      1.405151e-05  0.000106  0.000024  0.000066  4.781744e-05
#            DPW     -1.341852e-05  0.000015 -0.000041  0.000017  1.329525e-05
#            ADS      8.058661e-06  0.000087  0.000029  0.000049  2.607024e-05
#            ^GDAXI  -6.082508e-07  0.000037 -0.000008  0.000025  1.812338e-05
#            BA      -5.981745e-05 -0.000017 -0.000130  0.000014  2.067056e-05
#            VOD     -3.479067e-05  0.000083 -0.000037  0.000056  4.208932e-05
#            BATS     5.409273e-06 -0.000033 -0.000018 -0.000009 -2.502094e-06
#            SDR      3.286412e-05 -0.000001  0.000034  0.000005  2.735464e-06
# ...                          ...       ...       ...       ...           ...
# 2007-12-31 EUR2Y             NaN       NaN       NaN       NaN           NaN
#            EUR1Y             NaN       NaN       NaN       NaN           NaN
#            EUR6MTH           NaN       NaN       NaN       NaN           NaN
#            EUR3MTH           NaN       NaN       NaN       NaN           NaN
#            GBP/EUR           NaN       NaN       NaN       NaN           NaN
#            USD/EUR           NaN       NaN       NaN       NaN           NaN
#            BAS               NaN       NaN       NaN       NaN           NaN
#            DPW               NaN       NaN       NaN       NaN           NaN
#            ADS               NaN       NaN       NaN       NaN           NaN
#            ^GDAXI            NaN       NaN       NaN       NaN           NaN
#            BA                NaN       NaN       NaN       NaN           NaN
#            VOD               NaN       NaN       NaN       NaN           NaN
#            BATS              NaN       NaN       NaN       NaN           NaN
#            SDR               NaN       NaN       NaN       NaN           NaN
#            EZJ               NaN       NaN       NaN       NaN           NaN
#            ^FTSE             NaN       NaN       NaN       NaN           NaN
#            F                 NaN       NaN       NaN       NaN           NaN
#            GE                NaN       NaN       NaN       NaN           NaN
#            AMD               NaN       NaN       NaN       NaN           NaN
#            NFLX              NaN       NaN       NaN       NaN           NaN
#            TSCO              NaN       NaN       NaN       NaN           NaN
#            ANSS              NaN       NaN       NaN       NaN           NaN
#            MA                NaN       NaN       NaN       NaN           NaN
#            AAPL              NaN       NaN       NaN       NaN           NaN
#            ROST              NaN       NaN       NaN       NaN           NaN
#            ^GSPC             NaN       NaN       NaN       NaN           NaN
#            RI.PA             NaN       NaN       NaN       NaN           NaN
#            AI.PA             NaN       NaN       NaN       NaN           NaN
#            BNP.PA            NaN       NaN       NaN       NaN           NaN
#            ^FCHI             NaN       NaN       NaN       NaN           NaN
#
#                     ...     USD1Y     USD2Y     USD3Y     USD5Y      USD7Y  \
# Date                ...
# 2020-02-14 GBP5Y    ... -0.325919  6.930829  6.721161  5.712613   7.541280
#            GBP3Y    ... -0.017723  6.580870  6.333262  5.743549   7.426474
#            GBP2Y    ... -0.008975  6.046104  5.794556  5.224423   6.782983
#            GBP1Y    ... -0.133398  4.534373  4.304604  3.547312   4.791164
#            USD10Y   ...  1.551406  6.044134  5.744807  6.078262   7.483146
#            USD7Y    ...  2.427595  7.222015  6.857663  8.660765  10.069483
#            USD5Y    ...  2.395666  5.521107  5.296201  7.806453   8.660765
#            USD3Y    ...  0.927440  6.135313  5.809845  5.296201   6.857663
#            USD2Y    ...  1.284411  6.614464  6.135313  5.521107   7.222015
#            USD1Y    ...  2.636534  1.284411  0.927440  2.395666   2.427595
#            USD6MTH  ... -0.680167 -0.609600 -0.283730  0.337302   0.030256
#            USD3MTH  ... -1.406548  1.327218  1.511509  0.493607   0.990337
#            EUR10Y   ... -0.112434  3.927424  3.920375  3.477269   4.517596
#            EUR7Y    ... -0.459299  3.735801  3.743409  2.953860   4.004349
#            EUR5Y    ... -0.659662  3.345655  3.367240  2.427990   3.410529
#            EUR3Y    ... -0.652834  2.444197  2.486793  1.706507   2.444025
#            EUR2Y    ... -0.463976  1.623797  1.679782  1.232945   1.711731
#            EUR1Y    ... -0.057823  0.377203  0.446239  0.620513   0.682127
#            EUR6MTH  ...  0.255437 -0.474954 -0.401267  0.227581  -0.003276
#            EUR3MTH  ...  0.445112 -0.974579 -0.899586 -0.000408  -0.404008
#            GBP/EUR  ... -0.005261  0.005475  0.005658 -0.001128   0.001325
#            USD/EUR  ... -0.002347  0.000903  0.001112 -0.001122  -0.000541
#            BAS      ...  0.011515  0.009654  0.009094  0.025591   0.025305
#            DPW      ...  0.000155  0.019138  0.017917  0.011405   0.017272
#            ADS      ...  0.010837  0.006973  0.006384  0.020828   0.019727
#            ^GDAXI   ...  0.004065  0.010950  0.010249  0.012384   0.014713
#            BA       ... -0.012626  0.039416  0.037278  0.011351   0.025726
#            VOD      ...  0.003779  0.024331  0.022694  0.024904   0.030153
#            BATS     ... -0.001075  0.001446  0.001016 -0.004799  -0.003022
#            SDR      ...  0.007637 -0.010052 -0.010356 -0.001586  -0.005110
# ...                 ...       ...       ...       ...       ...        ...
# 2007-12-31 EUR2Y    ...       NaN       NaN       NaN       NaN        NaN
#            EUR1Y    ...       NaN       NaN       NaN       NaN        NaN
#            EUR6MTH  ...       NaN       NaN       NaN       NaN        NaN
#            EUR3MTH  ...       NaN       NaN       NaN       NaN        NaN
#            GBP/EUR  ...       NaN       NaN       NaN       NaN        NaN
#            USD/EUR  ...       NaN       NaN       NaN       NaN        NaN
#            BAS      ...       NaN       NaN       NaN       NaN        NaN
#            DPW      ...       NaN       NaN       NaN       NaN        NaN
#            ADS      ...       NaN       NaN       NaN       NaN        NaN
#            ^GDAXI   ...       NaN       NaN       NaN       NaN        NaN
#            BA       ...       NaN       NaN       NaN       NaN        NaN
#            VOD      ...       NaN       NaN       NaN       NaN        NaN
#            BATS     ...       NaN       NaN       NaN       NaN        NaN
#            SDR      ...       NaN       NaN       NaN       NaN        NaN
#            EZJ      ...       NaN       NaN       NaN       NaN        NaN
#            ^FTSE    ...       NaN       NaN       NaN       NaN        NaN
#            F        ...       NaN       NaN       NaN       NaN        NaN
#            GE       ...       NaN       NaN       NaN       NaN        NaN
#            AMD      ...       NaN       NaN       NaN       NaN        NaN
#            NFLX     ...       NaN       NaN       NaN       NaN        NaN
#            TSCO     ...       NaN       NaN       NaN       NaN        NaN
#            ANSS     ...       NaN       NaN       NaN       NaN        NaN
#            MA       ...       NaN       NaN       NaN       NaN        NaN
#            AAPL     ...       NaN       NaN       NaN       NaN        NaN
#            ROST     ...       NaN       NaN       NaN       NaN        NaN
#            ^GSPC    ...       NaN       NaN       NaN       NaN        NaN
#            RI.PA    ...       NaN       NaN       NaN       NaN        NaN
#            AI.PA    ...       NaN       NaN       NaN       NaN        NaN
#            BNP.PA   ...       NaN       NaN       NaN       NaN        NaN
#            ^FCHI    ...       NaN       NaN       NaN       NaN        NaN
#
#                       USD10Y     GBP1Y     GBP2Y     GBP3Y     GBP5Y
# Date
# 2020-02-14 GBP5Y    6.263098  5.660369  7.623208  8.340107  8.991446
#            GBP3Y    6.004061  5.328447  7.182650  7.834624  8.340107
#            GBP2Y    5.476447  4.916543  6.598347  7.182650  7.623208
#            GBP1Y    3.980559  3.731011  4.916543  5.328447  5.660369
#            USD10Y   6.052341  3.980559  5.476447  6.004061  6.263098
#            USD7Y    7.483146  4.791164  6.782983  7.426474  7.541280
#            USD5Y    6.078262  3.547312  5.224423  5.743549  5.712613
#            USD3Y    5.744807  4.304604  5.794556  6.333262  6.721161
#            USD2Y    6.044134  4.534373  6.046104  6.580870  6.930829
#            USD1Y    1.551406 -0.133398 -0.008975 -0.017723 -0.325919
#            USD6MTH -0.266988 -0.080156  0.121198  0.199913  0.308557
#            USD3MTH  1.109724  1.616919  2.128127  2.350453  2.717238
#            EUR10Y   3.851890  3.077959  4.157482  4.557647  4.908982
#            EUR7Y    3.520465  3.075165  4.114504  4.509623  4.920832
#            EUR5Y    3.071843  2.860587  3.797233  4.158015  4.569161
#            EUR3Y    2.234787  2.163156  2.853357  3.119772  3.435960
#            EUR2Y    1.538713  1.452934  1.924246  2.103505  2.306332
#            EUR1Y    0.507148  0.332040  0.485992  0.537230  0.560731
#            EUR6MTH -0.198768 -0.442287 -0.494967 -0.527475 -0.623919
#            EUR3MTH -0.615559 -0.896134 -1.066320 -1.146501 -1.311323
#            GBP/EUR  0.003326  0.006040  0.007539  0.008327  0.010105
#            USD/EUR  0.000230  0.001560  0.001929  0.002144  0.002744
#            BAS      0.014816  0.004474  0.007762  0.008274  0.005554
#            DPW      0.016360  0.014153  0.018179  0.019746  0.021494
#            ADS      0.010432  0.002402  0.005361  0.005929  0.004111
#            ^GDAXI   0.011291  0.006896  0.009537  0.010365  0.010380
#            BA       0.028719  0.034910  0.043112  0.046467  0.051818
#            VOD      0.021391  0.019449  0.026440  0.028455  0.029046
#            BATS     0.000463  0.000472 -0.000900 -0.001314 -0.001358
#            SDR     -0.006063 -0.011103 -0.014829 -0.016510 -0.019725
# ...                      ...       ...       ...       ...       ...
# 2007-12-31 EUR2Y         NaN       NaN       NaN       NaN       NaN
#            EUR1Y         NaN       NaN       NaN       NaN       NaN
#            EUR6MTH       NaN       NaN       NaN       NaN       NaN
#            EUR3MTH       NaN       NaN       NaN       NaN       NaN
#            GBP/EUR       NaN       NaN       NaN       NaN       NaN
#            USD/EUR       NaN       NaN       NaN       NaN       NaN
#            BAS           NaN       NaN       NaN       NaN       NaN
#            DPW           NaN       NaN       NaN       NaN       NaN
#            ADS           NaN       NaN       NaN       NaN       NaN
#            ^GDAXI        NaN       NaN       NaN       NaN       NaN
#            BA            NaN       NaN       NaN       NaN       NaN
#            VOD           NaN       NaN       NaN       NaN       NaN
#            BATS          NaN       NaN       NaN       NaN       NaN
#            SDR           NaN       NaN       NaN       NaN       NaN
#            EZJ           NaN       NaN       NaN       NaN       NaN
#            ^FTSE         NaN       NaN       NaN       NaN       NaN
#            F             NaN       NaN       NaN       NaN       NaN
#            GE            NaN       NaN       NaN       NaN       NaN
#            AMD           NaN       NaN       NaN       NaN       NaN
#            NFLX          NaN       NaN       NaN       NaN       NaN
#            TSCO          NaN       NaN       NaN       NaN       NaN
#            ANSS          NaN       NaN       NaN       NaN       NaN
#            MA            NaN       NaN       NaN       NaN       NaN
#            AAPL          NaN       NaN       NaN       NaN       NaN
#            ROST          NaN       NaN       NaN       NaN       NaN
#            ^GSPC         NaN       NaN       NaN       NaN       NaN
#            RI.PA         NaN       NaN       NaN       NaN       NaN
#            AI.PA         NaN       NaN       NaN       NaN       NaN
#            BNP.PA        NaN       NaN       NaN       NaN       NaN
#            ^FCHI         NaN       NaN       NaN       NaN       NaN
#
# [141036 rows x 46 columns]

# %%
ewma_cov.index.droplevel() == "^FCHI"
# Out:
# array([False, False, False, ..., False, False,  True])

# %%
ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna().unstack().index
# Out:
# DatetimeIndex(['2020-02-14', '2020-02-13', '2020-02-12', '2020-02-11',
#                '2020-02-10', '2020-02-07', '2020-02-06', '2020-02-05',
#                '2020-02-04', '2020-02-03',
#                ...
#                '2008-01-15', '2008-01-14', '2008-01-11', '2008-01-10',
#                '2008-01-09', '2008-01-08', '2008-01-07', '2008-01-04',
#                '2008-01-03', '2008-01-02'],
#               dtype='datetime64[ns]', name='Date', length=3065, freq=None)

# %%
df = df.iloc[::-1]

# %%
betas = pd.DataFrame(ewma_cov[ewma_cov.index.droplevel() == "RI.PA"][["^FCHI"]].dropna()["^FCHI"].values/ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna()["^FCHI"].values,columns=["RI.PA"],index = ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna().unstack().index)

# %%
tickers_fr = ['BNP.PA', 'AI.PA', 'RI.PA']
tickers_us = ['ROST', 'AAPL', 'MA','ANSS', 'TSCO', 'NFLX', 'AMD', 'GE', 'F']
ticker_uk = ['EZJ', 'SDR', 'BATS','VOD', 'BA']
ticker_de = ['ADS', 'DPW', 'BAS']

# %%
betas_fr = pd.DataFrame()
for ticker in tickers_fr:
    betas_fr[ticker] = ewma_cov[ewma_cov.index.droplevel() == ticker][["^FCHI"]].dropna()["^FCHI"].values/ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna()["^FCHI"].values

# %%
betas_fr.index = ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna().unstack().index

# %%
betas_us = pd.DataFrame()
for ticker in tickers_us:
    betas_us[ticker] = ewma_cov[ewma_cov.index.droplevel() == ticker][["^GSPC"]].dropna()["^GSPC"].values/ewma_cov[ewma_cov.index.droplevel() == "^GSPC"][["^GSPC"]].dropna()["^GSPC"].values

# %%
 betas_us.index = ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna().unstack().index

# %%
betas_uk = pd.DataFrame()
for ticker in ticker_uk:
    betas_uk[ticker] = ewma_cov[ewma_cov.index.droplevel() == ticker][["^FTSE"]].dropna()["^FTSE"].values/ewma_cov[ewma_cov.index.droplevel() == "^FTSE"][["^FTSE"]].dropna()["^FTSE"].values

# %%
betas_uk.index = ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna().unstack().index

# %%
betas_de = pd.DataFrame()
for ticker in ticker_de:
    betas_de[ticker] = ewma_cov[ewma_cov.index.droplevel() == ticker][["^FTSE"]].dropna()["^FTSE"].values/ewma_cov[ewma_cov.index.droplevel() == "^FTSE"][["^FTSE"]].dropna()["^FTSE"].values

# %%
betas_de.index = ewma_cov[ewma_cov.index.droplevel() == "^FCHI"][["^FCHI"]].dropna().unstack().index

# %%
betas = pd.concat([betas_fr,betas_us,betas_uk,betas_de],axis=1)

# %%
mapping = pd.read_excel("mapping.xlsx",index_col = "risk_factors")

# %%
np.dot(mapping["exposure_EUR"].T.values,np.dot(,mapping["exposure_EUR"].values))
# Out:
#   File "<ipython-input-21-c291a90f9bc1>", line 1
#     np.dot(mapping["exposure_EUR"].T.values,np.dot(,mapping["exposure_EUR"].values))
#                                                    ^
# SyntaxError: invalid syntax

# %%
ewma_cov.loc[betas.index[0]]

# %%
alpha = 0.01
var = pd.DataFrame()
cpt_EUR = []
for num in range(0,3064):
    cpt_EUR.append(norm.ppf(1-alpha) * np.sqrt(np.dot(mapping["exposure_EUR"].T.values,np.dot(ewma_cov.loc[betas.index[num]].values,mapping["exposure_EUR"].values))))

# %%
riskmetrics_var = pd.DataFrame(cpt_EUR,columns = ["var_1%_eur"],index = betas.index[0:3064])

# %%
riskmetrics_var

# %%
alpha = 0.01
cpt_pct = []
for num in range(0,3064):
    cpt_pct.append(norm.ppf(1-alpha) * np.sqrt(np.dot(mapping["exposure_pct"].T.values,np.dot(ewma_cov.loc[betas.index[num]].values,mapping["exposure_pct"].values))))

# %%
riskmetrics_var["var_1%_%"] = cpt_pct

# %%
riskmetrics_var[["var_1%_%"]].plot()
plt.show()

# %%
total_portfolio_value = 1137816.44

# %%
portfolio_rt_bin = []
for date in df.index:
    portfolio_rt_bin.append(np.dot(df.loc[date].values,mapping["total_exposure"].values)/total_portfolio_value)

# %%
portfolio = pd.DataFrame(portfolio_rt_bin,columns=["portfolio_returns"],index = df.index)

# %%
portfolio_mapped_rt_bin = []
for date in df.index:
    portfolio_mapped_rt_bin.append(np.dot(df.loc[date].values,mapping["mapped_exposure"].values)/total_portfolio_value)

# %%
portfolio["mapped_portfolio_returns"] = portfolio_mapped_rt_bin

# %%
portfolio.dropna(inplace=True)

# %%
portfolio
# Out:
#             portfolio_returns  mapped_portfolio_returns
# Date
# 2020-02-14          -0.000514                  0.000189
# 2020-02-13          -0.000807                  0.000028
# 2020-02-12           0.005778                  0.002521
# 2020-02-11           0.002303                  0.001151
# 2020-02-10          -0.002105                  0.003168
# 2020-02-07           0.002164                 -0.000981
# 2020-02-06           0.005827                  0.000649
# 2020-02-05           0.000211                  0.003363
# 2020-02-04          -0.001649                  0.005656
# 2020-02-03           0.006563                  0.000702
# 2020-01-31          -0.004984                 -0.005896
# 2020-01-30          -0.003547                  0.000075
# 2020-01-29          -0.001968                  0.000304
# 2020-01-28           0.004452                  0.002766
# 2020-01-27          -0.008695                 -0.005217
# 2020-01-24           0.004383                 -0.001335
# 2020-01-23           0.007991                  0.001018
# 2020-01-22          -0.000550                  0.001397
# 2020-01-21           0.004852                 -0.000926
# 2020-01-20          -0.003506                 -0.000677
# 2020-01-17          -0.000913                  0.002425
# 2020-01-16          -0.001867                  0.003064
# 2020-01-15           0.001587                  0.001190
# 2020-01-14           0.005215                  0.000668
# 2020-01-13           0.001097                  0.001027
# 2020-01-10           0.004444                 -0.001122
# 2020-01-09           0.004717                  0.001161
# 2020-01-08           0.010774                  0.000899
# 2020-01-07           0.001155                 -0.000503
# 2020-01-06           0.001935                  0.000975
# ...                       ...                       ...
# 2008-02-12           0.000303                  0.003198
# 2008-02-11           0.003840                 -0.000235
# 2008-02-08           0.006320                  0.001467
# 2008-02-07          -0.003249                  0.001360
# 2008-02-06          -0.000368                 -0.003451
# 2008-02-05           0.001377                 -0.005406
# 2008-02-04          -0.001074                 -0.002232
# 2008-02-01           0.002112                  0.004744
# 2008-01-31           0.023160                  0.007705
# 2008-01-30           0.000672                 -0.002998
# 2008-01-29           0.003948                  0.002657
# 2008-01-28          -0.002701                  0.002346
# 2008-01-25          -0.007504                 -0.003032
# 2008-01-24          -0.008322                  0.001911
# 2008-01-23           0.005438                  0.006859
# 2008-01-22           0.006606                  0.003168
# 2008-01-21          -0.004535                 -0.003646
# 2008-01-18           0.001091                 -0.000379
# 2008-01-17          -0.002679                 -0.008062
# 2008-01-16          -0.002735                  0.001111
# 2008-01-15          -0.009678                 -0.008356
# 2008-01-14          -0.001629                  0.001909
# 2008-01-11          -0.007739                 -0.004400
# 2008-01-10           0.005878                 -0.000619
# 2008-01-09          -0.009667                  0.003187
# 2008-01-08          -0.025946                 -0.006027
# 2008-01-07           0.006110                  0.002222
# 2008-01-04          -0.013600                 -0.008876
# 2008-01-03          -0.000880                  0.002500
# 2008-01-02          -0.007411                 -0.005485
#
# [3065 rows x 2 columns]

# %%
from scipy.special import beta
import numpy as np
from math import sqrt
from typing import Union
from scipy import integrate

# Generalised Student T probability Distribution
def generalized_student_t(x:Union[float, np.ndarray], mu:float, sigma:float, 
                          lam:float, p:float, q:float) \
        -> Union[float, np.ndarray]:


    v = q**(-1/p) * ((3*lam**2 + 1)*(beta(3/p, q - 2/p)/beta(1/p,q)) - 4*lam**2*(beta(2/p, q - 1/p)/beta(1/p,q))**2)**(-1/2)

    m = 2*v*sigma*lam*q**(1/p)*beta(2/p,q - 1/p)/beta(1/p,q)   

    fx = p  / (2*v*sigma*q**(1/p)*beta(1/p,q)*(abs(x-mu+m)**p/(q*(v*sigma)**p)*(lam*np.sign(x-mu+m)+1)**p + 1)**(1/p + q))

    return fx
